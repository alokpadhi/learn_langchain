# %% [markdown]
# ## 📋 Types of Models in LangChain
#
# ### **1. LLMs (Language Models)**
# - Input: String
# - Output: String
# - Use case: Simple text completion (legacy, less common now)
#
# ### **2. Chat Models**
# - Input: List of messages
# - Output: Message
# - Use case: **Most common** - conversational AI, structured interactions
# - Examples: GPT-4, Claude, Gemini, Llama
#
# ### **3. Text Embedding Models**
# - Input: Text
# - Output: Vector of numbers (embeddings)
# - Use case: Semantic search, RAG, similarity comparison

# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    model="llama3.2",
    temperature=0.8
)

# %%
response = llm.invoke("Explain machine learning to a 10 year old")

# %%
print(response.content)
# Out:
# Imagine you have a super smart robot friend who can learn new things from you. That's basically what machine learning is!
#
# Machine learning is a way for computers to get better at doing things on their own, without being told exactly how to do it. It's like teaching your robot friend a game or a skill.
#
# Here's an example: Let's say you want your robot friend to recognize pictures of different animals, like dogs and cats. At first, the robot might not be very good at it, but as you show it more and more pictures, it starts to learn what makes a dog look like a dog and what makes a cat look like a cat.
#
# Over time, the robot gets better and better at recognizing animals, until it can do it all by itself! That's basically machine learning in action.
#
# There are different types of machine learning, but one common type is called "supervised learning". This means that the computer is shown lots of examples of something (like pictures of animals) and then tries to figure out how to recognize it. It's like having a big class where you learn from your teacher!
#
# Machine learning is used in all sorts of cool things, like:
#
# * Self-driving cars that can navigate roads
# * Virtual assistants like Siri or Alexa that can understand what we say
# * Games that can get better at being fun and challenging
#
# So, machine learning is like teaching a super smart robot friend to do new things, and it's used in lots of amazing ways to make our lives easier and more fun!

# %%
llm = ChatOllama(
    model="llama3.2",
    
    # Creativity control
    temperature=0.7,  # 0-1, higher = more random
    
    # Length control
    max_tokens=500,  # Maximum response length
    
    # Determinism
    seed=42,  # Some providers support reproducible outputs
    
    # Advanced sampling
    top_p=0.9,  # Nucleus sampling (alternative to temperature)
    frequency_penalty=0.0,  # Penalize repetition (-2.0 to 2.0)
    presence_penalty=0.0,   # Encourage new topics (-2.0 to 2.0)
    
    # Streaming
    streaming=True,  # Enable token-by-token streaming
)

# %% [markdown]
# ### **Temperature Guide**

# %%
# Temperature = 0 → Deterministic, factual
llm_factual = ChatOllama(model="llama3.2",temperature=0)
# Good for: Math, coding, factual Q&A

# Temperature = 0.7 → Balanced
llm_balanced = ChatOllama(model="llama3.2",temperature=0.7)
# Good for: General conversation, explanations

# Temperature = 1.0+ → Creative
llm_creative = ChatOllama(model="llama3.2",temperature=1.2)
# Good for: Creative writing, brainstorming

# %% [markdown]
# ## 🔍 Understanding Model Response Objects

# %%
llm = ChatOllama(model="llama3.2")
response = llm.invoke("Hello!")

# %%
print(type(response))
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
print(response.content)
# Out:
# How can I assist you today?

# %%
print(response.response_metadata)
# Out:
# {'model': 'llama3.2', 'created_at': '2025-11-14T16:30:07.718005278Z', 'done': True, 'done_reason': 'stop', 'total_duration': 90156590, 'load_duration': 26800635, 'prompt_eval_count': 27, 'prompt_eval_duration': 9893106, 'eval_count': 8, 'eval_duration': 53180020, 'model_name': 'llama3.2', 'model_provider': 'ollama'}

# %% [markdown]
# ## 🚀 Async Support

# %%
import asyncio
from langchain_ollama import ChatOllama

# %%
async def async_example():
    llm = ChatOllama(model="llama3.2")

    # single async call
    response = await llm.ainvoke("what is async programming")
    print(response.content)

    # batch async calls (will be executed in parallel)
    prompts = [
        "what is python?",
        "what is Javascript",
        "What is Rust",
    ]

    responses = await llm.abatch(prompts)
    for i, resp in enumerate(responses):
        print(f"\n{prompts[i]}")
        print(resp.content)

await async_example()
# Out:
# Async (Asynchronous) Programming is a paradigm that allows for non-blocking, concurrent execution of tasks. It enables multiple tasks to run simultaneously without waiting for each other, improving the overall performance and responsiveness of an application.
#
# **What is asynchronous?**
#
# In traditional synchronous programming, a task completes one after another, where each task waits for the previous one to finish before starting. In contrast, asynchronous programming allows tasks to execute concurrently, allowing them to overlap in time. This means that while one task is executing, another task can start running without waiting for the first one to complete.
#
# **Key characteristics of async programming:**
#
# 1. **Non-blocking**: Async tasks do not block or wait for each other to finish.
# 2. **Concurrent execution**: Multiple tasks can run simultaneously.
# 3. **Event-driven**: Async programming is often driven by events, such as user input, network requests, or timer events.
#
# **Benefits of async programming:**
#
# 1. **Improved responsiveness**: Users perceive an application as more responsive when it handles multiple tasks concurrently.
# 2. **Increased throughput**: By running multiple tasks in parallel, async programming can improve overall performance and efficiency.
# 3. **Better resource utilization**: By minimizing blocking and waiting, async programming allows for better use of system resources.
#
# **Common async programming techniques:**
#
# 1. **Callbacks**: A function that is executed when a task completes or an event occurs.
# 2. **Promises**: A mechanism for handling asynchronous operations that returns a value after completion.
# 3. **Futures**: An object that represents the result of an asynchronous operation, which can be used to handle errors and await results.
#
# **Examples of async programming:**
#
# 1. Web APIs (e.g., AJAX requests)
# 2. Node.js event-driven I/O
# 3. Asynchronous database operations
# 4. Concurrent processing in parallel computing
#
# **Common challenges with async programming:**
#
# 1. **Managing complexity**: Coordinating multiple concurrent tasks can be complex and difficult to manage.
# 2. **Error handling**: Async programming requires careful error handling to avoid issues like deadlocks or lost messages.
# 3. **Debugging**: Async programming can make debugging more challenging due to the non-linear nature of execution.
#
# **Best practices for async programming:**
#
# 1. **Use a consistent threading model**: Choose a specific threading model (e.g., single-threaded, multi-threaded) and stick to it.
# 2. **Use async libraries or frameworks**: Leverage established libraries or frameworks that handle async programming complexities.
# 3. **Keep tasks short-lived**: Break down long-running tasks into smaller, independent operations.
#
# By understanding the principles of async programming, developers can write more efficient, responsive, and scalable applications that take advantage of modern computing architectures.
#
# what is python?
# Python is a high-level, interpreted programming language that is widely used for various purposes such as web development, scientific computing, data analysis, artificial intelligence, and more. It was created in the late 1980s by Guido van Rossum and was first released in 1991.
#
# Here are some key features of Python:
#
# 1. **Easy to learn**: Python has a simple syntax and is often taught as a first programming language due to its readability and simplicity.
# 2. **High-level language**: Python is a high-level language, meaning it abstracts away many low-level details, allowing developers to focus on the logic of their program without worrying about memory management or other details.
# 3. **Interpreted language**: Python code is interpreted by the interpreter, which means that the code is executed line-by-line, rather than compiled all at once.
# 4. **Object-oriented**: Python supports object-oriented programming (OOP) concepts such as classes, objects, inheritance, and polymorphism.
# 5. **Large standard library**: Python has a vast collection of libraries and modules that provide access to various functionality, including file I/O, networking, and data structures.
#
# Some common use cases for Python include:
#
# 1. **Web development**: Python is used in web frameworks such as Django and Flask to build web applications.
# 2. **Data analysis**: Python is widely used in data science and scientific computing due to its extensive libraries and tools, including NumPy, pandas, and scikit-learn.
# 3. **Artificial intelligence**: Python is used in AI and machine learning tasks, including deep learning, natural language processing, and computer vision.
# 4. **Automation**: Python is used to automate tasks and processes, such as data scraping, file management, and system administration.
# 5. **Education**: Python is often taught in introductory programming courses due to its simplicity and ease of use.
#
# Some popular applications built with Python include:
#
# 1. YouTube
# 2. Instagram
# 3. Pinterest
# 4. Dropbox
# 5. Reddit
#
# Overall, Python is a versatile and powerful language that has become one of the most popular languages for software development, data analysis, and machine learning tasks.
#
# what is Javascript
# JavaScript is a high-level, dynamic, and interpreted programming language that is primarily used for client-side scripting on the web. It was created by Brendan Eich in 1995 while he worked at Netscape Communications Corporation.
#
# JavaScript allows developers to add interactivity to web pages by enabling them to create dynamic content, respond to user interactions, and update the document content dynamically. It's often used for:
#
# 1. **Client-side scripting**: JavaScript is executed on the client-side (i.e., in the browser), allowing for fast and efficient execution of code.
# 2. **Dynamic content**: JavaScript can be used to update the content of web pages based on user interactions, such as button clicks or form submissions.
# 3. **Form validation**: JavaScript can validate user input data to ensure it meets certain conditions before submitting the form.
# 4. **Events handling**: JavaScript can handle events such as mouse clicks, key presses, and scroll events, allowing for responsive and interactive web pages.
#
# JavaScript is widely used in various applications, including:
#
# 1. **Web development**: JavaScript is a fundamental skill for web developers, used to create dynamic web pages, web applications, and mobile applications.
# 2. **Desktop and mobile applications**: JavaScript can be used to build desktop and mobile applications using frameworks like Electron, React Native, or Angular Mobile.
# 3. **Game development**: JavaScript is often used in game development, particularly with libraries like Phaser or Pixi.js.
# 4. **Server-side programming**: With Node.js, JavaScript can be used for server-side programming, allowing developers to create scalable and high-performance server applications.
#
# JavaScript has several popular frameworks and libraries that make it easier to build complex web applications, such as:
#
# 1. React
# 2. Angular
# 3. Vue.js
# 4. Ember.js
#
# Some of the key features of JavaScript include:
#
# 1. **Dynamic typing**: JavaScript is dynamically typed, which means you don't need to declare variable types before using them.
# 2. **Object-oriented programming**: JavaScript supports object-oriented programming (OOP) concepts like inheritance and encapsulation.
# 3. **First-class functions**: JavaScript functions are first-class citizens, meaning they can be passed around as arguments or returned from other functions.
# 4. **Asynchronous programming**: JavaScript has built-in support for asynchronous programming using callbacks, promises, or async/await.
#
# Overall, JavaScript is a versatile and widely-used programming language that plays a crucial role in building modern web applications and desktop/mobility applications.
#
# What is Rust
# Rust is a systems programming language that aims to provide memory safety guarantees without compromising performance. It was created in 2006 by Graydon Hoare and is now maintained by the Rust Foundation, a non-profit organization.
#
# Rust's primary goal is to eliminate common errors in C-like languages, such as:
#
# 1. Memory leaks: Rust uses ownership and borrowing system to manage memory, which prevents memory leaks.
# 2. Null pointer dereferences: Rust's borrow checker ensures that null pointers are handled safely.
# 3. Data corruption: Rust's ownership and borrow system prevent data corruption by ensuring that variables are accessed consistently.
#
# Rust achieves this through a combination of features:
#
# 1. Ownership system: Variables have an owner, which is responsible for deallocating the memory when it goes out of scope.
# 2. Borrowing system: Variables can be borrowed from their owners, allowing multiple parts of code to access shared data safely.
# 3. Type system: Rust has a strong type system that ensures types are consistent and safe.
# 4. Memory safety guarantees: Rust's borrow checker and ownership system ensure memory safety guarantees.
#
# Rust is designed to be:
#
# 1. **Safe**: Rust prevents common errors in C-like languages, ensuring code reliability.
# 2. **Concise**: Rust has a clean and simple syntax, making it easy to write efficient code.
# 3. **Performance-oriented**: Rust's compile-time evaluation of code and its focus on performance make it suitable for systems programming.
#
# Some key features of Rust include:
#
# * **Multithreading**: Rust provides high-level APIs for building concurrent programs safely and efficiently.
# * **Smart pointers**: Rust has a range of smart pointer types, which manage memory automatically.
# * **Error handling**: Rust's error handling system is designed to be expressive and safe.
#
# Rust has gained popularity in recent years due to its innovative approach to systems programming, and it is now used in various projects, including:
#
# 1. **Operating systems**: Rust is used in several operating systems, such as the Linux kernel.
# 2. **Databases**: Rust is used in databases like RocketSQL.
# 3. **Networking libraries**: Rust's networking library (tokio) provides a modern and efficient way to build network applications.
#
# Overall, Rust is a powerful and innovative language that aims to provide memory safety guarantees without compromising performance, making it an attractive choice for systems programming projects.

# %% [markdown]
# ## 🌊 Streaming Responses

# %%
for chunk in llm.stream("write a short poen about python programming."):
    print(chunk.content, end="", flush=True)
print()
# Out:
# Here's a short poem:
#
# In the land of code, where variables roam,
# Python reigns supreme, in its coding home.
# Indentation is key, to logic so fine,
# A syntax so gentle, it's truly divine.
#
# Indians and foreigners alike unite,
# To write with ease, through day and night.
# Loops and lists, they dance with glee,
# In this world of code, where Python sets me free.
